# %%
from dask.distributed import Client,SSHCluster

# %% [markdown]
# This way of creating multinode is not right see the next one

# %%
cluster_hosts=['localhost','localhost','172.20.250.40']

usernames=['hduser_','hduser_','sysadm']

passwd=['hduser17','hduser17','system']
cluster1=SSHCluster(['localhost','localhost','172.20.250.40'],
                    connect_options=['username':usernames,
                                     'password':passwd]
)
client=Client(cluster1)
# Out:
#   Cell In[2], line 7
#     connect_options=['username':usernames,
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# Right One

# %%
cluster_hosts=['localhost','localhost','172.20.250.40','172.20.251.22']

usernames=['hduser_','hduser_','sysadm','sysadm']

passwd=['hduser17','hduser17','system','system']
cluster1=SSHCluster(cluster_hosts,
                    connect_options=[{'username':usernames[0],'password':passwd[0]},
                                     {'username':usernames[1],'password':passwd[1]},
                                     {'username':usernames[2],'password':passwd[2]},
                                     {'username':usernames[3],'password':passwd[3]}],
                    worker_options={'nthreads':6}                 
                    
)
client=Client(cluster1)
# Out:
# 2024-04-09 01:57:17,563 - distributed.deploy.ssh - INFO - 2024-04-09 01:57:17,563 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2024-04-09 01:57:17,566 - distributed.deploy.ssh - INFO - /home/hduser_/.local/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# 2024-04-09 01:57:17,567 - distributed.deploy.ssh - INFO - Perhaps you already have a cluster running?
# 2024-04-09 01:57:17,567 - distributed.deploy.ssh - INFO - Hosting the HTTP server on port 35021 instead
# 2024-04-09 01:57:17,568 - distributed.deploy.ssh - INFO - warnings.warn(
# 2024-04-09 01:57:17,569 - distributed.deploy.ssh - INFO - 2024-04-09 01:57:17,566 - distributed.scheduler - INFO - State start
# 2024-04-09 01:57:17,571 - distributed.deploy.ssh - INFO - 2024-04-09 01:57:17,571 - distributed.scheduler - INFO -   Scheduler at: tcp://172.20.250.207:41737
# ...

# %%
client
# Out:
# <Client: 'tcp://172.20.250.207:41737' processes=3 threads=18, memory=22.87 GiB>

# %%
client.close()

# %%
client
# Out:
# <Client: 'tcp://172.20.250.207:38219' processes=3 threads=18, memory=22.87 GiB>
